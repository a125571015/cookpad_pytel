# %% [markdown]
# # Import library

# %%
import requests
from bs4 import BeautifulSoup
import os
import json
import random,time
from random import randint
import re
import urllib
import sys
from urllib import request
from datetime import datetime
import pandas as pd
from pandas.core.frame import DataFrame
from datetime import datetime

# %% [markdown]
# # 寫入檔案相關

# %%
def create_mkdir():
    ####建立資料夾
    mydir='cookpad_check'
    mydir_save_img="cookpad_save_img_check"
    mydir_save_log='cookpad_log_check'
    mydir_save_title_log='cookpad_title_log_check'
    
    if os.path.exists(mydir):
        print('mrdir name cookpad has been create')
    else:
        os.mkdir(mydir)

    if os.path.exists(mydir_save_img):
        print("mrdir name cookpad_save_img has been create")
    else:
        os.mkdir(mydir_save_img)
    
    if os.path.exists(mydir_save_log):
        print("mrdir name cookpad_save_log has been create")
    else:
        os.mkdir(mydir_save_log)
    if os.path.exists(mydir_save_title_log):
        print('mydir name cookpad_save_title has been create')
    else:
        os.mkdir(mydir_save_title_log)

# %%
def write_to_file(write_file_list):
    import requests
from bs4 import BeautifulSoup
import os
import json
import random,time
from random import randint
import re
import urllib
import sys
from urllib import request
from datetime import datetime
import pandas as pd
from pandas.core.frame import DataFrame
from datetime import datetime

def create_mkdir():
    ####建立資料夾
    mydir='cookpad'
    mydir_save_img="cookpad_save_img"
    mydir_save_log='cookpad_log'
    mydir_save_title_log='cookpad_title_log'
    
    if os.path.exists(mydir):
        print('mrdir name cookpad has been create')
    else:
        os.mkdir(mydir)

    if os.path.exists(mydir_save_img):
        print("mrdir name cookpad_save_img has been create")
    else:
        os.mkdir(mydir_save_img)
    
    if os.path.exists(mydir_save_log):
        print("mrdir name cookpad_save_log has been create")
    else:
        os.mkdir(mydir_save_log)
    if os.path.exists(mydir_save_title_log):
        print('mydir name cookpad_title_log has been create')
    else:
        os.mkdir(mydir_save_title_log)
#######

#####寫入檔案相關
def write_to_file(write_file_list):
    with open('./cookpad/'+save_name+'.txt','w',encoding="utf-8") as es:
        es.write(title_name+'|'+'\n')
        es.write(arthor+'|'+'\n')
        es.write(img+'|'+'\n')
        es.write(Number_of_copies+'|'+'\n')
        es.write(cook_time+'|'+'\n')
        es.write(set_food+'|'+'\n')
        es.write(set_food_count+'|'+'\n')
        es.write(set_step+'|'+'\n')
        print('寫檔完成')

def save_img(img):
    if img!="na":
        print("進入寫入圖片前")
        request.urlretrieve(img, './cookpad_save_img/{}.jpg'.format(save_name))#寫入圖片
        print("圖片下載完成")
    else:
        print("image not found")
def save_log(set_next_url):
    with open('./cookpad_log/'+str(set_next_url)+'_log'+'.txt','w',encoding="utf-8") as es2:
        es2.write(getnextpageurl)
    
def save_title_log(set_title_log_url):
    with open('./cookpad_title_log/'+str(set_title_log_url)+"_title_log"+'.txt','w',encoding='utf-8')as es3:
        es3.write(title_url)
def save_total_log(set_total_items):
    with open
    pass
def list_to_csv(list_save):
    data=DataFrame(list_save)#这时候是以行为标准写入的
    print(data)
    now = datetime.now()
    s1 = datetime.strftime(now,'%Y-%m-%d')
    s2= datetime.strftime(now,'%H:%M:%S')
    s2=s2.replace(":","_")
    #print (type(now))
    #print (now)
    #print (s1)
    #print(s2)
    save_file_data_time=s1+"_"+s2
    #print(s.replace(" ","")))
    data.to_csv('cookpad{}.csv'.format(save_file_data_time),header=False,index=False,encoding='utf-8-sig')        

######## 


####文章控制相關
def count_time():
    time_strat=time.time()
    #time.sleep(5)
    time.sleep(randint(5,15))
    time_end=time.time()
    print(time_end-time_strat)

def get_main_body(url):
    headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:75.0) Gecko/20100101 Firefox/75.0'}
    ss=requests.session()
    res=ss.get(url,headers=headers)
    cookies=ss.cookies.get_dict()
    #print(ss.cookies.get_dict())

    res=ss.get(url,headers=headers,cookies=cookies)
    soup=BeautifulSoup(res.text,'html.parser')
    return soup

#食材,食材數量,步驟

def setfood_and_set_food_count_step(food_test):
    set_food=''
    set_step=''
    set_food_count=''
    step_number=1
    for x in food_test:
        get_food=x.select('div')[0].text
        #print(get_food)
        check_len=len(get_food.split(' '))
        #print(check_len)
        try:
            get_food=get_food.split(' ')[8]
            set_food=set_food+get_food+' '
        except(IndexError):
            print('get_food陣列沒有第8個值')
        #print(get_food)
        get_food_count=x.select('div')[0].select('bdi')[0].text
    
        set_food_count=set_food_count+get_food_count+" "
    for z in step:
        get_step=z.text
        set_step=set_step+str(step_number)+"."+get_step
        step_number=step_number+1

    return set_food, set_food_count  ,set_step      

    
def check_title_log_url(title_url):
    count_wrong=5
    save_list=[]   
    #建立檢查的list
    #test='./cookpad_title_log_check/1_泰式檸檬魚簡易版.txt'
    test_list=os.listdir('./cookpad_title_log/')
    #print(test_list)
    for i in test_list:
        with open ('./cookpad_title_log/'+i,'r',encoding='utf-8')as es4:
            data=es4.read()
        #print(data)
            save_list.append(data)
    
    for g in save_list:
        if g==title_url:
           count_wrong=6
     
           
    if count_wrong==6:
        print("這個url已經重複了,程式不寫入檔案" )
        return count_wrong
    else:
        print("這個url沒有重複,程式繼續")
        return count_wrong

######

create_mkdir()

###一些計數器變數    
url="https://cookpad.com/tw?after=1592711907.0"
set_next_url_count=1
set_next_url=1     #nextlogurl編號
set_total_items=245 #檔案編號
set_while_stop=1
list_save=[['食譜名稱', '作者','圖片','份數', '料理時間', '食材','食材數量', '料理步驟']]
tep_list=[]
save_next_html=[]#存下檢查爬到哪裡了
set_food=''
set_step=''
log_list_save=[['編號','網站']]
######

while (set_while_stop==1):
#for go  in  range(1,3):
    get_main_body(url)    
    soup=get_main_body(url)
    #print(soup)    
    mainbody=soup.select('div.media')
    getnextpageurl="https://cookpad.com"+soup.select('div#feed_pagination')[0].select('a')[0]['href']
    save_next_html.append(getnextpageurl)#紀錄html
    

    for i in mainbody:
        
        print("第{}筆資料".format(set_total_items))
        title=i.select('div.media__body')[0].select('a.flex-grow')[0]['aria-label']
        test2=i.select('div.media__body')[0].select('a.flex-grow')[0]
        title_url="https://cookpad.com"+i.select('div.media__body')[0].select('a.flex-grow')[0]['href']
        url=title_url
        get_main_body(url)
        soup=get_main_body(url)
        #print(soup)
    
        print(title)
        #print(test2)
        print(title_url)
        
        count_time()
        #如果img沒有抓到
        img=soup.select('div.tofu_image')
        if len(img)<=0:
            print("img is not found")
            img="na"
        else:
            img=img[0].select('img')[0]['src']
            split_img=img.split(':')[1]#進行切片防止:被轉碼
            test=urllib.parse.quote(split_img)#網址中文轉碼
            img="https:"+test#進行網址重組
        title_name=soup.select('section.intro-container')[0].select('h1.break-words')[0].text
        #artice=soup.select('div.recipe-show__story')[0].select('p.mb-2')[0].text.split('#')[0]
        
        arthor=soup.select('section.document__section.media.author-container')[0].select('span.text-cookpad-16')[0].text
        cook_time=soup.select('div.p-3.border-t.border-quaternary.text-center.text-secondary')
        if len(cook_time) <= 0 :
            cook_time = "Na"
            print("cook_tine is na")
        else:
            cook_time = cook_time[0].select('span.px-4')[0].text #有些資料沒有
           
        food_test=soup.select('div.ingredient-list')[0].select('ol.list-unstyled.text-cookpad-18')[0].select('li')
        Number_of_copies=soup.select('div.text-secondary.mt-2')[0].text
        if len(Number_of_copies.split())<=0:
            Number_of_copies='na'
        else:
            print('Number_of_copies is alive')
    
            
        step=soup.select('ol.numbered-list')[0].select('p.mb-2')
            
        set_food, set_food_count ,set_step= setfood_and_set_food_count_step(food_test)   
       
        
        step_number=1#重設步驟變數
        #food_total_and_food_step(food_test,step,step_number)
        
        #print(img)
        #print(title_name)
        #print(artice)
        #print(Awards)
        #print(arthor)
        #print(cook_time)
        #print(food_total)
        #print(set_food)
        #print(set_step)
        #print(img)
        #print(Number_of_copies)
        #存入資料
        title_name=title_name.replace(" ","")
        set_food=set_food.replace(" ","")
            
        tep_list.append(title_name)
        tep_list.append(arthor)
        tep_list.append(img)
        tep_list.append(Number_of_copies)
        tep_list.append(cook_time)
        tep_list.append(set_food)
        tep_list.append(set_food_count)
        tep_list.append(set_step)
        list_save.append(tep_list)
        
        #print(list_save)
        tep_list=[]
        # write_to_file(img, content, cook, cook_time)
           
        #print(list_save)
        #print("_____________________________________")
            
        #print("正規化檔名前")
        #print("_____________________________________")
        string=title_name
        re_title_name=re.sub(u"([^\u4e00-\u9fa5\u0030-\u0039\u0041-\u005a\u0061-\u007a])","",string)
        #print(re_title_name)
        save_name_id=str(set_total_items)
        save_name=save_name_id+"_"+re_title_name
        
        count_wrong=check_title_log_url(title_url)
        
        if count_wrong!=6:
            print("程式繼續")
        else:
            set_total_items+=1
            print("程式不寫檔")
            continue
            
        
        
        #print(save_name)
        #print("正規化檔名後")
            
            
            
            
        #print("_____________________________________")
        
        #print(入寫檔前')
        
        write_file_list=[title_name, arthor, img, Number_of_copies,cook_time,set_food,set_food_count,set_step]
        write_to_file(write_file_list)
        save_title_log(save_name)    
        save_img(img)    
 
                
           
            
        print("_____________________________________")
            
        
      
        set_total_items+=1

    #寫入next_URL_LOG       
    save_log(set_next_url)
    set_next_url+=1
    
    url=getnextpageurl
    print("+++++++換頁+++++++++++++++++")
    print("第{}個頁面".format(set_next_url_count))
    
    print(getnextpageurl)
    set_next_url_count+=1
"""
    if set_total_items==1001:
        set_while_stop=set_while_stop-1
        print("已經有一千筆資料了")  
"""    

if getnextpageurl=='https://cookpad.com/tw?after=1526305209.0':
    set_while_stop=set_while_stop-1
    
    

print(set_total_items-1)

list_to_csv(list_save)

# %% [markdown]
# # Save Log

# %%
def save_img(img):
    if img!="na":
        print("進入寫入圖片前")
        request.urlretrieve(img, './cookpad_save_img_check/{}.jpg'.format(save_name))#寫入圖片
        print("圖片下載完成")
    else:
        print("image not found")
def save_log(set_next_url):
    with open('./cookpad_log_check/'+str(set_next_url)+'.txt','w',encoding="utf-8") as es2:
        es2.write(format(getnextpageurl))
    
def save_title_log(set_title_log_url):
    with open('./cookpad_title_log_check/'+str(set_title_log_url)+'.txt','w',encoding='utf-8')as es3:
        es3.write(title_url)
        print('log save_title open')

# %%
def list_to_csv(list_save):
    data=DataFrame(list_save)#这时候是以行为标准写入的
    print(data)
    now = datetime.now()
    s1 = datetime.strftime(now,'%Y-%m-%d')
    s2= datetime.strftime(now,'%H:%M:%S')
    s2=s2.replace(":","_")
    #print (type(now))
    #print (now)
    #print (s1)
    #print(s2)
    save_file_data_time=s1+"_"+s2
    #print(s.replace(" ","")))
    data.to_csv('cookpad{}.csv'.format(save_file_data_time),header=False,index=False,encoding='utf-8-sig')        

######## 


####文章控制相關
def count_time():
    time_strat=time.time()
    #time.sleep(5)
    time.sleep(randint(2,6))
    time_end=time.time()
    print(time_end-time_strat)

def get_main_body(url):
    headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:75.0) Gecko/20100101 Firefox/75.0'}
    ss=requests.session()
    res=ss.get(url,headers=headers)
    cookies=ss.cookies.get_dict()
    #print(ss.cookies.get_dict())

    res=ss.get(url,headers=headers,cookies=cookies)
    soup=BeautifulSoup(res.text,'html.parser')
    return soup


    
    
def check_title_log_url(title_url):
    count_wrong=5
    save_list=[]   
    #建立檢查的list
    #test='./cookpad_title_log_check/1_泰式檸檬魚簡易版.txt'
    test_list=os.listdir('./cookpad_title_log_check/')
    #print(test_list)
    for i in test_list:
        with open ('./cookpad_title_log_check/'+i,'r',encoding='utf-8')as es4:
            data=es4.read()
        #print(data)
            save_list.append(data)
    
    for g in save_list:
        if g==title_url:
           count_wrong=6
     
           
    if count_wrong==6:
        print("這個url已經重複了,程式即將停止" )
        return count_wrong
    else:
        print("這個url沒有重複,程式繼續")
        
    #print(save_list)

     
def setfood_and_set_food_count_step(food_test):
    set_food=''
    set_step=''
    set_food_count=''
    step_number=1
    for x in food_test:
        get_food=x.select('div')[0].text
        #print(get_food)
        check_len=len(get_food.split(' '))
        #print(check_len)
        try:
            get_food=get_food.split(' ')[8]
            set_food=set_food+get_food+' '
        except(IndexError):
            print('get_food陣列沒有第8個值')
        #print(get_food)
        get_food_count=x.select('div')[0].select('bdi')[0].text
    
        set_food_count=set_food_count+get_food_count+" "
    for z in step:
        get_step=z.text
        set_step=set_step+str(step_number)+"."+get_step
        step_number=step_number+1

    return set_food, set_food_count  ,set_step      
######
"""
set_food=''
set_step=''
set_food_count=''
step_number=1
for x in food_test:
    get_food=x.select('div')[0].text
    #print(get_food)
    check_len=len(get_food.split(' '))
    #print(check_len)
    if check_len==10:
        get_food=get_food.split(' ')[8]
        set_food=set_food+get_food+' '
    #print(get_food)
    get_food_count=x.select('div')[0].select('bdi')[0].text
    
    set_food_count=set_food_count+get_food_count+" "
for z in step:
    get_step=z.text
    set_step=set_step+str(step_number)+"."+get_step
    step_number=step_number+1






"""





create_mkdir()

###一些計數器變數    
url="https://cookpad.com/tw"
set_next_url_count=1
set_next_url=1
set_total_items=87 #檔案編號
set_while_stop=1
list_save=[['食譜名稱', '作者','圖片','份數', '料理時間', '食材','食材數量', '料理步驟']]
tep_list=[]
save_next_html=[]#存下檢查爬到哪裡了
set_food=''
set_step=''
log_list_save=[['編號','網站']]
count_wrong=5
######

#while (set_while_stop==1):
for go  in  range(1,3):
    get_main_body(url)    
    soup=get_main_body(url)
    #print(soup)    
    mainbody=soup.select('div.media')
    getnextpageurl="https://cookpad.com"+soup.select('div#feed_pagination')[0].select('a')[0]['href']
    save_next_html.append(getnextpageurl)#紀錄html
    

    for i in mainbody:
        
        print("第{}筆資料".format(set_total_items))
        title=i.select('div.media__body')[0].select('a.flex-grow')[0]['aria-label']
        test2=i.select('div.media__body')[0].select('a.flex-grow')[0]
        title_url="https://cookpad.com"+i.select('div.media__body')[0].select('a.flex-grow')[0]['href']
        url=title_url
        print(url)
       
        soup=get_main_body(url)
        #print(soup)
    
        #print(title)
        #print(test2)
        #print(title_url)
        
        count_time()
        #如果img沒有抓到
        img=soup.select('div.tofu_image')
        if len(img)<=0:
            print("img is not found")
            img="na"
        else:
            img=img[0].select('img')[0]['src']
            split_img=img.split(':')[1]#進行切片防止:被轉碼
            test=urllib.parse.quote(split_img)#網址中文轉碼
            img="https:"+test#進行網址重組
        title_name=soup.select('section.intro-container')[0].select('h1.break-words')[0].text
        #artice=soup.select('div.recipe-show__story')[0].select('p.mb-2')[0].text.split('#')[0]
        
        arthor=soup.select('section.document__section.media.author-container')[0].select('span.text-cookpad-16')[0].text
        cook_time=soup.select('div.p-3.border-t.border-quaternary.text-center.text-secondary')
        if len(cook_time) <= 0 :
            cook_time = "Na"
            print("cook_tine is na")
        else:
            cook_time = cook_time[0].select('span.px-4')[0].text #有些資料沒有
           
        food_test=soup.select('div.ingredient-list')[0].select('ol.list-unstyled.text-cookpad-18')[0].select('li')
        Number_of_copies=soup.select('div.text-secondary.mt-2')[0].text
        if len(Number_of_copies.split())<=0:
            Number_of_copies='na'
        else:
            print('Number_of_copies is alive')
    
            
        step=soup.select('ol.numbered-list')[0].select('p.mb-2')
            
           
     
        set_food, set_food_count ,set_step= setfood_and_set_food_count_step(food_test)
#         for x in food_test:
#             get_food=x.select('div')[0].text
#             #print(get_food)
#             get_food=get_food.split(' ')[8]
#             #print(get_food)
#             get_food_count=x.select('div')[0].select('bdi')[0].text
#             set_food=set_food+get_food+'\n'
#             set_food_count=set_food_count+get_food_count+"\n"
   
      
        
        step_number=1#重設步驟變數
        #food_total_and_food_step(food_test,step,step_number)
        
        #print(img)
        #print(title_name)
        #print(artice)
        #print(Awards)
        #print(arthor)
        #print(cook_time)
        #print(food_total)
        #print(set_food)
        #print(set_step)
        #print(img)
        #print(Number_of_copies)
        #存入資料
        title_name=title_name.replace(" ","")
        set_food=set_food.replace(" ","")
            
       
        
        #print(list_save)
        tep_list=[]
        # write_to_file(img, content, cook, cook_time)
           
        #print(list_save)
        #print("_____________________________________")
            
        #print("正規化檔名前")
        #print("_____________________________________")
        string=title_name
        re_title_name=re.sub(u"([^\u4e00-\u9fa5\u0030-\u0039\u0041-\u005a\u0061-\u007a])","",string)
        #print(re_title_name)
        
        
        save_name_id=str(set_total_items)
        save_name=save_name_id+"_"+re_title_name
        
        count_wrong=check_title_log_url(title_url)
        
        if count_wrong!=6:
            print("程式繼續")
        else:
            set_total_items+=1
            print("程式不寫黨")
            continue
            
            
            
            
        #存入tmp_list
        tep_list.append(title_name)
        tep_list.append(arthor)
        tep_list.append(img)
        tep_list.append(Number_of_copies)
        tep_list.append(cook_time)
        tep_list.append(set_food)
        tep_list.append(set_food_count)
        tep_list.append(set_step)
        list_save.append(tep_list)
        
        #print(save_name)
        #print("正規化檔名後")
            
            
            
            
        #print("_____________________________________")
        
        #print(入寫檔前')
        
        write_file_list=[title_name, arthor, img, Number_of_copies,cook_time,set_food,set_food_count,set_step]
        write_to_file(write_file_list)
        save_title_log(save_name)    
        save_img(img)    
 
                
           
            
        print("_____________________________________")
            
        
      
        set_total_items+=1

    #寫入next_URL_LOG       
    save_log(set_next_url)
    set_next_url+=1
    
    url=getnextpageurl
    print("+++++++換頁+++++++++++++++++")
    print("第{}個頁面".format(set_next_url_count))
    
    print(getnextpageurl)
    set_next_url_count+=1
"""
    if set_total_items==1001:
        set_while_stop=set_while_stop-1
        print("已經有一千筆資料了")  
"""    

if getnextpageurl=='https://cookpad.com/tw?after=1526305209.0':
    set_while_stop=set_while_stop-1
    
    

print(set_total_items-1)

list_to_csv(list_save)
print("程式跑完了")
# Out:
# mrdir name cookpad has been create
# mrdir name cookpad_save_img has been create
# mrdir name cookpad_save_log has been create
# mydir name cookpad_save_title has been create
# 第87筆資料
# https://cookpad.com/tw/%E9%A3%9F%E8%AD%9C/12960932-%E7%84%97%E7%83%A4%E8%8C%84%E5%AD%90
# 4.000678539276123
# Number_of_copies is alive
# 這個url沒有重複,程式繼續
# 程式繼續
# 寫檔完成
# log save_title open
# 進入寫入圖片前
# 圖片下載完成
# _____________________________________
# 第88筆資料
# https://cookpad.com/tw/%E9%A3%9F%E8%AD%9C/12854410-%E4%B8%89%E6%9D%AF%E4%B9%9D%E5%B1%A4%E5%A1%94%E8%B1%86%E8%85%90
# 6.0000550746917725
# cook_tine is na
# Number_of_copies is alive
# 這個url已經重複了,程式即將停止
# 程式不寫黨
# 第89筆資料
# https://cookpad.com/tw/%E9%A3%9F%E8%AD%9C/12756910-%E8%8C%B6%E9%A6%99%E5%9B%9B%E6%BA%A2%E6%88%9A%E9%A2%A8%E8%9B%8B%E7%B3%95%F0%9F%8C%B1
# 5.000699281692505
# cook_tine is na
# Number_of_copies is alive
# 這個url已經重複了,程式即將停止
# 程式不寫黨
# 第90筆資料
# https://cookpad.com/tw/%E9%A3%9F%E8%AD%9C/12960573-%E7%84%A6%E7%B3%96%E5%9C%9F%E5%8F%B8
# 6.000061273574829
# Number_of_copies is alive
# 這個url已經重複了,程式即將停止
# 程式不寫黨
# 第91筆資料
# https://cookpad.com/tw/%E9%A3%9F%E8%AD%9C/12960308-%E7%B4%85%E8%B1%86%E7%85%8E%E9%A4%85
# 3.0000898838043213
# Number_of_copies is alive
# 這個url已經重複了,程式即將停止
# 程式不寫黨
# 第92筆資料
# https://cookpad.com/tw/%E9%A3%9F%E8%AD%9C/12668458-%E9%80%A0%E5%9E%8B%E9%A5%85%E9%A0%AD%E7%B2%89%E7%B4%85%E5%85%94%E5%85%94
# 5.000059127807617
# Number_of_copies is alive
# 這個url已經重複了,程式即將停止
# 程式不寫黨
# 第93筆資料
# https://cookpad.com/tw/%E9%A3%9F%E8%AD%9C/
://cookpad.com/tw/%E9%A3%9F%E8%AD%9C/12644975-%E6%B2%B9%E9%86%8B%E5%B0%8F%E9%BB%83%E7%93%9C%E6%8D%B2
# 3.0007410049438477
# cook_tine is na
# Number_of_copies is alive
# 這個url已經重複了,程式即將停止
# 程式不寫黨
# +++++++換頁+++++++++++++++++
# 第2個頁面
# https://cookpad.com/tw?after=1592782782.0
# 128
#           0          1                                                  2  \
# 0      食譜名稱         作者                                                 圖片
# 1  \n焗烤茄子\n  Philip Lo  https://img-global.cpcdn.com/recipes/5ef203ac8...
#
#             3               4                                              5  \
# 0          份數            料理時間                                             食材
# 1  \n 4人份\n    \n 1小時\n        茄子\n新鮮番茄糊\n洋蔥碎、蒜泥、黑胡椒、海鹽\nextra\nParmigiano\n
#
#                        6                                                  7
# 0                   食材數量                                               料理步驟
# 1  6 條\n適量\n適量\n少許\n適量\n  1.先將茄子洗淨抹乾後斜切片，再以篩網在兩面輕輕的鋪上一層麵粉，平底鍋入橄欖油將茄子片分別小...
# 程式跑完了

# %%
def check_title_log_url(title_url):

    count_wrong=5
    save_list=[]   
    
    #建立檢查的list
    #test='./cookpad_title_log_check/1_泰式檸檬魚簡易版.txt'
    test_list=os.listdir('./cookpad_title_log_check/')
    #print(test_list)

    for i in test_list:
        with open ('./cookpad_title_log_check/'+i,'r',encoding='utf-8')as es4:
            data=es4.read()
        #print(data)
            save_list.append(data)
    
    for g in save_list:
        if g==title_url:
           count_wrong=6
     
           
    if count_wrong==6:
        print("這個url已經重複了,程式即將停止" )
        return count_wrong
    else:
        print("這個url沒有重複,程式繼續")
    #print(save_list)

"""
#print(os.listdir('./cookpad_title_log_check/'))
with open('./cookpad_title_log_check/1_泰式檸檬魚簡易版.txt','r',encoding="utf-8") as es:
    data=es.read()
    #print(data)
save_check_url=data
print(data)

"""
count_wrong=check_title_log_url('https://cookpad.com/tw/%E9%A3%9F%E8%AD%9C/12954783-%E8%8A%9D%E5%BF%83%E6%AF%94%E8%96%A9')
print(count_wrong)
# Out:
# 這個url已經重複了,程式即將停止
# 6

# %%
import glob
test="./cookpad_title_log_check/*.txt"
for i in glob.glob(test):
    print(i)
# Out:
# ./cookpad_title_log_check\10_魷魚泡菜煎餅.txt
# ./cookpad_title_log_check\11_瓜子肉紅蔥火龍果拌麵.txt
# ./cookpad_title_log_check\12_玉米鮪魚優格抹醬不開火料理.txt
# ./cookpad_title_log_check\13_馬鈴薯煎餅.txt
# ./cookpad_title_log_check\14_豆皮漢堡.txt
# ./cookpad_title_log_check\15_荷葉糯米排骨.txt
# ./cookpad_title_log_check\16_涼拌芥末花枝.txt
# ./cookpad_title_log_check\17_油醋小黃瓜捲.txt
# ./cookpad_title_log_check\18_青椒炒肉絲.txt
# ./cookpad_title_log_check\19_夏日涼拌什錦絲.txt
# ./cookpad_title_log_check\1_泰式檸檬魚簡易版.txt
# ./cookpad_title_log_check\20_醬味小黃瓜.txt
# ./cookpad_title_log_check\21_氣炸鍋芒果奶酪塔.txt
# ./cookpad_title_log_check\22_椰漿萊姆雞丁.txt
# ./cookpad_title_log_check\23_麵包棒.txt
# ./cookpad_title_log_check\24_鮭魚雜炊定食美味升級.txt
# ./cookpad_title_log_check\25_巧克力黃金亞麻籽仁Biscotti.txt
# ./cookpad_title_log_check\26_奶酥醬.txt
# ./cookpad_title_log_check\27_香蕉鬆餅無麸食品.txt
# ./cookpad_title_log_check\28_五星級飲品在我家翻翻轉轉的蘋果綠夏日的抹茶牛奶.txt
# ./cookpad_title_log_check\29_冬瓜茶洋菜凍.txt
# ./cookpad_title_log_check\2_菜瓜吻仔魚粥.txt
# ./cookpad_title_log_check\30_超簡易夏天派對小吃蟹籽大蝦生菜蟹柳沙拉.txt
# ./cookpad_title_log_check\31_燒烤鮮魚排.txt
# ./cookpad_title_log_check\32_三杯魟魚.txt
# ./cookpad_title_log_check\33_烘焙咖啡豆okane.txt
# ./cookpad_title_log_check\34_三色水餃萍姊.txt
# ./cookpad_title_log_check\35_肉圓蒜蓉醬.txt
# ./cookpad_title_log_check\36_桂花蓮子蜜山藥懶人電子鍋版.txt
# ./cookpad_title_log_check\37_鐵板牛排炒飯.txt
# ./cookpad_title_log_check\38_巧克力豆餅乾.txt
# ./cookpad_title_log_check\39_蜜汁雞腿水波爐烤箱.txt
# ./cookpad_title_log_check\3_氣炸蒜香湯圓薯丁.txt
# ./cookpad_title_log_check\40_炸蝦.txt
# ./cookpad_title_log_check\41_允指回味的椒鹽排骨.txt
# ./cookpad_title_log_check\42_鹽焗鱸魚.txt
# ./cookpad_title_log_check\43_芝心比薩.txt
# ./cookpad_title_log_check\44_共食團辣炒土豆絲.txt
# ./cookpad_title_log_check\45_櫛瓜蝦仁蛋.txt
# ./cookpad_title_log_check\46_韭菜湯麵.txt
# ./cookpad_title_log_check\47_蜜汁雞腿卷.txt
# ./cookpad_title_log_check\48_綠竹筍炒肉絲.txt
# ./cookpad_title_log_check\49_青椒炒豬肉.txt
# ./cookpad_title_log_check\4_油飯飯粒型.txt
# ./cookpad_title_log_check\50_鹽水焗蝦.txt
# ./cookpad_title_log_check\51_涼拌小黃瓜.txt
# ./cookpad_title_log_check\52_天狗蝕日蛋蛋篇.txt
# ./cookpad_title_log_check\53_大白菜水餃.txt
# ./cookpad_title_log_check\54_夏日芒果莎莎醬.txt
# ./cookpad_title_log_check\55_綠豆湯.txt
# ./cookpad_title_log_check\56_蛤蜊燒賣.txt
# ./cookpad_title_log_check\57_金莎嫩雞.txt
# ./cookpad_title_log_check\58_甜醋薑片.txt
# ./cookpad_title_log_check\59_橙香醬燒雞.txt
# ./cookpad_title_log_check\5_泰式酸辣虱目嫩魚片新手健康簡易版.txt
# ./cookpad_title_log_check\60_芒果雪糕.txt
# ./cookpad_title_log_check\61_鯛魚味噌湯.txt
# ./cookpad_title_log_check\62_自製天然芒果冰淇淋.txt
# ./cookpad_title_log_check\63_柚香涼拌小黃瓜雞絲夏天必備低醣涼拌菜.txt
# ./cookpad_title_log_check\6_三色蒸蛋.txt
# ./cookpad_title_log_check\7_豆漿.txt
# ./cookpad_title_log_check\8_涼拌紫茄.txt
# ./cookpad_title_log_check\9_回鍋肉.txt
